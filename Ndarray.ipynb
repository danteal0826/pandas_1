# %% [markdown]
# <a href="https://colab.research.google.com/github/danteal0826/pandas_1/blob/main/Ndarray.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Desde Kaggle buscar
# un conjunto de datos (dataset) en formato CSV y construir (Google colab) un dataframe desde ese archivo CSV

# %% [markdown]
# #Ndarray
# problema: avaluo-> datos(numeros(float, int), texto)
# #Pandas: biblioteca de python que guarda diferente tipos de datos
# estructura de datas tipo tabla en donde se tiene filas (registros) y columnas<-**dataframe**
#
# **serie**->cada una de las columnas de un dataframe, es un arreglo unidimensional
#
# (Herramientas para LADM-Col -> pandas, R, matlab, geopandas(manejar dataframe que tenga datos geográficos))

# %%
# !pip install pandas

# %%
import pandas as pd

# %% [markdown]
# #Crear una serie
# Arreglo unidimensional de datos, para crear una serie se utiliza la funcion pd.Series

# %%
miSerie=pd.Series([34,56,78,23,34])
miSerie
# Out:
# 0    34
# 1    56
# 2    78
# 3    23
# 4    34
# dtype: int64

# %% [markdown]
# #Diccionario en Python
# Estructura que guarda datos en forma de objetos llave-valor
# {objeto en tipo diccionario en Python}
#
# podemos utilizarlos para crear dataframe

# %%
miDiccionario={
    "nombre": "Casa1",
    "área": 120,
    "baños": 3,
    "propietarios":[
        "Paulo", "Diana", "Sonia"
    ],
    "barrio":{
        "nombre": "Gran Britalia",
        "localidad": "Bosa"
    }
}

miDiccionario
# Out:
# {'nombre': 'Casa1',
#  'área': 120,
#  'baños': 3,
#  'propietarios': ['Paulo', 'Diana', 'Sonia'],
#  'barrio': {'nombre': 'Gran Britalia', 'localidad': 'Bosa'}}

# %% [markdown]
# #Dataframe
# Estructura de datos en format tabla.
#
# La forma "más simple" de crear un dataframe es apartir de un diccionario, otra forma puede ser desde hojas de cálculo, desde archivos JSON o desde archivos CSV(Valores separados por coma)

# %%
miDataframe=pd.DataFrame({'Si':[10,15], 'No':[50,68]})
miDataframe
# Out:
#    Si  No
# 0  10  50
# 1  15  68

# %% [markdown]
# ##Clase 24/04/24
# Otro dataframe
#
# La difernecia entre un ndarray y un dataframe es el tipo de datos que recibe el arreglo
#
# index-> para cambiar el nombre de los índices

# %%
encuesta=pd.DataFrame(
    {
        "Julia": ["Me gustó", "Fue horrible"],
        "Pedro": ["Fue delicioso", "No estuvo mal"],
    },
    index=["Restaurante_1", "Restaurante_2"]
)
encuesta
# Out:
#                       Julia          Pedro
# Restaurante_1      Me gustó  Fue delicioso
# Restaurante_2  Fue horrible  No estuvo mal

# %% [markdown]
# #Cargar archivos CSV en un dataframe

# %%
#Leer el archivo CSV
miCSV=pd.read_csv("/datos.csv")
miCSV.shape
miCSV.head()
# Out:
#    Estudiante_1   Estudinate_2   Estudiante_3
# 0            34             23             45
# 1            45             10             46
# 2            25             30             46

# %%
miTitanic=pd.read_csv("/titanic.csv")
miTitanic.shape
miTitanic.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         1

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
miDiabetes=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Diabetes.csv")
miDiabetes.shape
miDiabetes.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# describe-> datos estadististicos de las difernrets series del dataframe

# %%
miDiabetes.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# rename-> sirve para cambiar el nombre de las series, crea un nuevo dataframe
#
# inplace=True-> funciona para que el rename se aplique al dataframe que estamos trabajando

# %%
miDiabetes.rename(columns={"Glucose": "Glucosa"}, inplace=True)

# %%
miDiabetes.head()
# Out:
#    Pregnancies  Glucosa  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
miGlucosa=miDiabetes["Glucosa"]
miGlucosa.count()
# Out:
# 768

# %%
miGlucosa.product()
# Out:
# 0

# %% [markdown]
# #Seleccionar filas especificas (Filtrar filas)

# %%
miDiabetesFiltrado=miDiabetes[miDiabetes["Glucosa"]>0]
miDiabetesFiltrado.count()
# Out:
# Pregnancies                 763
# Glucosa                     763
# BloodPressure               763
# SkinThickness               763
# Insulin                     763
# BMI                         763
# DiabetesPedigreeFunction    763
# Age                         763
# Outcome                     763
# dtype: int64

# %%
#sumar todos los datos de glucosa

# %%
miTitanic=pd.read_csv("/content/titanic.csv")
miTitanic.shape
miTitanic.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         1

# %%
miTitanicFiltrado=miTitanic["Survived"]>0
miTitanicFiltrado.count()
miTitanic["Survived"].sum()
# Out:
# 153
